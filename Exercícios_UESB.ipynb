# %% [markdown]
# <a href="https://colab.research.google.com/github/calreis/PYTHON/blob/main/Exerc%C3%ADcios_UESB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lista de exercícios da UESB.

# %% [markdown]
# 1° Elaborar um programa Python para somar dois números.

# %%
n1 = int(input('Digite um valor: '))
n2 = int(input('Digite o segundo valor: '))

soma = n1 + n2
print(f'A soma de {n1} + {n2} = ',soma)

# %% [markdown]
# 2° Elaborar um programa Python para somar os digitos de um número menor que 100
